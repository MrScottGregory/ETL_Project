# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Vehicle Registration Data

# %%
# read in vehicle registration CSV
reg_csv_file = "Vehicle__Snowmobile__and_Boat_Registrations.csv"
vehicle_reg_df = pd.read_csv(reg_csv_file)

# %%
# explore the dataframe: review list of columns
vehicle_reg_df.columns
# Out:
# Index(['Record Type', 'VIN', 'Registration Class', 'City', 'State', 'Zip',
#        'County', 'Model Year', 'Make', 'Body Type', 'Fuel Type',
#        'Unladen Weight', 'Maximum Gross Weight', 'Passengers',
#        'Reg Valid Date', 'Reg Expiration Date', 'Color', 'Scofflaw Indicator',
#        'Suspension Indicator', 'Revocation Indicator'],
#       dtype='object')

# %%
# explore the dataframe: sample the top of the df
vehicle_reg_df.head()
# Out:
#   Record Type                VIN Registration Class             City State  \
# 0        VEH   5NPD84LF0JH355353                PAS  LINDENHURST        NY
# 1        VEH   JF1GJAA66EH010986                PAS  SLEEPY HOLLOW      NY
# 2        VEH   5NPE24AF5FH208042                PAS  FAIRPORT           NY
# 3        VEH   JF2GPAPC3F8320456                ORG  WESTBURY           NY
# 4        VEH   5NPE24AF5FH207974                PAS  MECHANICVILLE      NY
#
#      Zip        County  Model Year   Make Body Type Fuel Type  Unladen Weight  \
# 0  11757  SUFFOLK           2018.0  HYUND      4DSD  GAS               2976.0
# 1  10591  WESTCHESTER       2014.0  SUBAR      4DSD  GAS               3010.0
# 2  14450  MONROE            2015.0  HYUND      4DSD  GAS               3252.0
# 3  11590  NASSAU            2015.0  SUBAR      SUBN  GAS               3241.0
# 4  12118  SARATOGA          2015.0  HYUND      4DSD  GAS               3252.0
#
#    Maximum Gross Weight  Passengers Reg Valid Date Reg Expiration Date  Color  \
# 0                   NaN         NaN     11/19/2018          11/18/2020  BK
# 1                   NaN         NaN     10/03/2017          10/02/2019  WH
# 2                   NaN         NaN     11/02/2018          10/09/2020  GY
# 3                   NaN         NaN     01/11/2019          09/06/2020  WH
# 4                   NaN         NaN     03/05/2019          06/21/2020  GY
#
#   Scofflaw Indicator Suspension Indicator Revocation Indicator
# 0                  N                    N                    N
# 1                  N                    N                    N
# 2                  N                    N                    N
# 3                  N                    N                    N
# 4                  N                    N                    N

# %%
# explore the dataframe: determine how many Record Types exist
vehicle_reg_df.groupby(['Record Type']).count()
# Out:
#                   VIN  Registration Class      City     State       Zip  \
# Record Type
# BOAT           359921              359921    359921    359921    359921
# SNOW           105451              105451    105451    105451    105451
# TRL            760594              760594    760594    760594    760594
# VEH          10713500            10713500  10713500  10713500  10713500
#
#                County  Model Year      Make  Body Type  Fuel Type  \
# Record Type
# BOAT           359921      359893    359921     359921     359921
# SNOW           105451      105451    105451     105451     105451
# TRL            760594      760594    760594     760594     760594
# VEH          10713500    10713500  10713500   10713500   10713500
#
#              Unladen Weight  Maximum Gross Weight  Passengers  Reg Valid Date  \
# Record Type
# BOAT                      0                     0           0          359921
# SNOW                      0                     0           0          105451
# TRL                  109183                651410           0          760594
# VEH                 9610478                768654      334226        10713499
#
#              Reg Expiration Date     Color  Scofflaw Indicator  \
# Record Type
# BOAT                      359921    359921              359921
# SNOW                      105451    105451              105451
# TRL                       760594    760594              760594
# VEH                     10524941  10713500            10713500
#
#              Suspension Indicator  Revocation Indicator
# Record Type
# BOAT                       359921                359921
# SNOW                       105451                105451
# TRL                        760594                760594
# VEH                      10713500              10713500

# %%
# retain only those rows with a record type VEH (we only want vehicles, vs boats etc)
# note that record type has 4 characters, so we need to leave a space after VEH
veh_reg_df = vehicle_reg_df[vehicle_reg_df["Record Type"]== "VEH "]
veh_reg_df.tail()
# Out:
#          Record Type                VIN Registration Class             City  \
# 10713495        VEH   JF2GPBBC0GH241471                PAS  SARATOGA SPRGS
# 10713496        VEH   JF2GPBBC0GH226100                PAS  STATEN ISLAND
# 10713497        VEH   JF2GPBBC0GH224315                PAS  ST LOUIS
# 10713498        VEH   JF2GPBBC0GH203612                PAS  BROOKLYN
# 10713499        VEH   JF2GPBBC0GH203576                PSD  MARCY
#
#          State    Zip        County  Model Year   Make Body Type Fuel Type  \
# 10713495    NY  12866  SARATOGA          2016.0  SUBAR      SUBN  GAS
# 10713496    NY  10302  RICHMOND          2016.0  SUBAR      SUBN  GAS
# 10713497    MO  63101  WESTCHESTER       2016.0  SUBAR      SUBN  GAS
# 10713498    NY  11218  KINGS             2016.0  SUBAR      SUBN  GAS
# 10713499    NY  13403  ONEIDA            2016.0  SUBAR      SUBN  GAS
#
#           Unladen Weight  Maximum Gross Weight  Passengers Reg Valid Date  \
# 10713495          3451.0                   NaN         NaN     05/09/2019
# 10713496          3451.0                   NaN         NaN     01/14/2019
# 10713497          3451.0                   NaN         NaN     02/13/2018
# 10713498          3451.0                   NaN         NaN     10/22/2017
# 10713499          3451.0                   NaN         NaN     11/18/2015
#
#          Reg Expiration Date  Color Scofflaw Indicator Suspension Indicator  \
# 10713495          06/18/2021  BK                     N                    N
# 10713496          01/30/2021  WH                     N                    N
# 10713497          03/31/2020  WH                     N                    N
# 10713498          12/03/2019  GR                     N                    N
# 10713499                 NaN  WH                     N                    N
#
#          Revocation Indicator
# 10713495                    N
# 10713496                    N
# 10713497                    N
# 10713498                    N
# 10713499                    N

# %%
# drop columns not relevant to our analysis
registration_df = veh_reg_df.drop(columns=['Record Type',
                                           'Fuel Type', 
                                           'Maximum Gross Weight', 
                                           'Passengers',
                                           'Scofflaw Indicator'])

# %%
# we want to clean up "Body Type" for joining with other data
# let's start by reviewing how many body types exist
# decode the body types here: https://data.ny.gov/api/views/w4pv-hbkt/files/AUsdC2Y0iEymGyebFASIjDxZ7irrm1-_yS-o9qFzWTQ?download=true&filename=NYSDMV_VehicleSnowmobileAndBoat_Registration_Data%20Dictionary.pdf
registration_df["Body Type"].value_counts()
# Out:
# SUBN    4966416
# 4DSD    3589210
# PICK     457423
# 2DSD     453108
# MCY      325935
# VAN      231510
# CONV     178701
# ATV      115525
# DUMP      82336
# BUS       60472
# UTIL      41219
# TRAC      36178
# H/WH      25720
# DELV      24813
# FLAT      17463
# TRLR      14131
# TAXI      11075
# P/SH      10104
# STAK      10065
# TANK       8539
# TOW        6711
# MOPD       6635
# REFG       5381
# SEDN       5139
# RBM        4780
# LTRL       4302
# RD/S       2487
# CMIX       2448
# TR/C       2283
# SEMI       1799
# AMBU       1318
# LSV        1225
# S/SP        988
# FIRE        981
# LIM         879
# T/CR        858
# HRSE        840
# SWT         775
# SN/P        725
# EMVR        566
# W/DR        466
# DCOM        370
# CUST        341
# ????        270
# W/SR        251
# H/TR        218
# R/RD        216
# MCC          81
# FPM          81
# LSVT         41
# H/IN         28
# BOAT         26
# TR/E         20
# RPLC         12
# LOCO         11
# TRAV          3
# POLE          2
# Name: Body Type, dtype: int64

# %%
# we notice that there are still some boats and snowplows, so let's eliminate those
registration_df = registration_df[(registration_df['Body Type'] != 'TRAV') & 
                                 (registration_df['Body Type'] != 'BOAT')]

# %%
# let's aggregate some of the body types together and convert to readable names
# remember, values have 4 characters, so:
# we need to add a space after any 3 character value, and let's rename so none are left
replace_values = {'4DSD' : 'SEDAN', '2DSD' : 'SEDAN', 'SEDN' : 'SEDAN',
                  'PICK' : 'PASS_TRUCK', 'VAN ' : 'PASS_TRUCK', 'LTRL' : 'PASS_TRUCK', 'SWT ' : 'PASS_TRUCK',
                  '????' : 'OTHER', 'RPLC' :'OTHER', 'CUST' : 'OTHER',
                  'AMBU' : 'EMERGENCY', 'FIRE' : 'EMERGENCY', 'DCOM' : 'EMERGENCY',
                  'CMIX' : 'MACHINE', 'P/SH' : 'MACHINE', 'S/SP' : 'MACHINE', 'SN/P' : 'MACHINE', 'EMVR' : 'MACHINE', 'W/DR' : 'MACHINE', 'W/SR': 'MACHINE', 'MCC ': 'MACHINE', 'FPM ' : 'MACHINE', 'LOCO' : 'MACHINE', 'RBM ' : 'MACHINE', 'RD/S' : 'MACHINE',
                  'DELV' : 'COMM_TRUCK', 'DUMP' : 'COMM_TRUCK', 'UTIL' : 'COMM_TRUCK', 'TRAC' : 'COMM_TRUCK', 'FLAT' : 'COMM_TRUCK', 'TRLR' : 'COMM_TRUCK', 'STAK' : 'COMM_TRUCK', 'TANK' : 'COMM_TRUCK', 'TOW ' : 'COMM_TRUCK', 'REFG' : 'COMM_TRUCK', 'TR/C' : 'COMM_TRUCK', 'SEMI' : 'COMM_TRUCK', 'T/CR' : 'COMM_TRUCK', 'H/TR' : 'COMM_TRUCK', 'R/RD' : 'COMM_TRUCK', 'TR/E' : 'COMM_TRUCK', 'POLE' : 'COMM_TRUCK',
                  'HRSE' : 'HEARSE', 'H/IN' : 'HEARSE',
                  'H/WH' : 'HOUSE_ON_WHEELS',
                  'LIM ' : 'TAXI',
                  'LSV ' : 'LOW_SPEED_VEH', 'LSVT': 'LOW_SPEED_VEH',
                  'MCY ' : 'CYCLES', 'MOPD' : 'CYCLES',
                  'SUBN' : 'SUBURBAN',
                  'ATV ' : 'ATV',
                  'BUS ' : 'BUS'
                 }
new_registration_df = registration_df.replace({'Body Type': replace_values})

# %%
# review updated list of body types
new_registration_df['Body Type'].value_counts()
# Out:
# SUBURBAN           4966416
# SEDAN              4047457
# PASS_TRUCK          694010
# CYCLES              332570
# COMM_TRUCK          252232
# CONV                178701
# ATV                 115525
# BUS                  60472
# HOUSE_ON_WHEELS      25720
# MACHINE              22988
# TAXI                 11954
# EMERGENCY             2669
# LOW_SPEED_VEH         1266
# HEARSE                 868
# OTHER                  623
# Name: Body Type, dtype: int64

# %%
new_registration_df.head()
# Out:
#                  VIN Registration Class             City State    Zip  \
# 0  5NPD84LF0JH355353                PAS  LINDENHURST        NY  11757
# 1  JF1GJAA66EH010986                PAS  SLEEPY HOLLOW      NY  10591
# 2  5NPE24AF5FH208042                PAS  FAIRPORT           NY  14450
# 3  JF2GPAPC3F8320456                ORG  WESTBURY           NY  11590
# 4  5NPE24AF5FH207974                PAS  MECHANICVILLE      NY  12118
#
#          County  Model Year   Make Body Type  Unladen Weight Reg Valid Date  \
# 0  SUFFOLK           2018.0  HYUND     SEDAN          2976.0     11/19/2018
# 1  WESTCHESTER       2014.0  SUBAR     SEDAN          3010.0     10/03/2017
# 2  MONROE            2015.0  HYUND     SEDAN          3252.0     11/02/2018
# 3  NASSAU            2015.0  SUBAR  SUBURBAN          3241.0     01/11/2019
# 4  SARATOGA          2015.0  HYUND     SEDAN          3252.0     03/05/2019
#
#   Reg Expiration Date  Color Suspension Indicator Revocation Indicator
# 0          11/18/2020  BK                       N                    N
# 1          10/02/2019  WH                       N                    N
# 2          10/09/2020  GY                       N                    N
# 3          09/06/2020  WH                       N                    N
# 4          06/21/2020  GY                       N                    N

# %%
# review column names  
new_registration_df.columns
# Out:
# Index(['VIN', 'Registration Class', 'City', 'State', 'Zip', 'County',
#        'Model Year', 'Make', 'Body Type', 'Unladen Weight', 'Reg Valid Date',
#        'Reg Expiration Date', 'Color', 'Suspension Indicator',
#        'Revocation Indicator'],
#       dtype='object')

# %%
# since the collision data is just for NYC, we want to narrow this data to NYC as well
# currently we have data for all counties in NY state
new_registration_df['County'].value_counts()
# Out:
# SUFFOLK         1198571
# NASSAU           999836
# QUEENS           857635
# ERIE             669265
# WESTCHESTER      665576
# MONROE           538456
# KINGS            536248
# ONONDAGA         332508
# BRONX            296304
# ORANGE           277654
# RICHMOND         275019
# NEW YORK         257469
# ALBANY           230658
# DUTCHESS         229057
# ROCKLAND         214194
# SARATOGA         190189
# OUT-OF-STATE     167466
# ONEIDA           164925
# NIAGARA          155968
# ULSTER           144276
# BROOME           138612
# SCHENECTADY      118418
# RENSSELAER       116413
# CHAUTAUQUA        90388
# ONTARIO           88914
# OSWEGO            87842
# PUTNAM            86354
# JEFFERSON         79721
# ST LAWRENCE       74934
# WAYNE             74653
#                  ...
# CHEMUNG           60025
# SULLIVAN          59303
# CAYUGA            56290
# WARREN            55367
# CATTARAUGUS       55344
# MADISON           52334
# COLUMBIA          51381
# WASHINGTON        48589
# LIVINGSTON        48159
# HERKIMER          47028
# GENESEE           45864
# OTSEGO            44547
# GREENE            41314
# FULTON            40239
# MONTGOMERY        38701
# CHENANGO          38188
# TIOGA             38146
# DELAWARE          37368
# FRANKLIN          35750
# ALLEGANY          32252
# CORTLAND          32167
# WYOMING           31562
# ESSEX             29560
# ORLEANS           29163
# SCHOHARIE         26132
# SENECA            24435
# LEWIS             23065
# YATES             17679
# SCHUYLER          15247
# HAMILTON           5096
# Name: County, Length: 63, dtype: int64

# %%
# through trail and error we learned there are trailing blank characters in the county values
# so let's remove any trailing space with .str.strip() 
new_registration_df['County'] = new_registration_df['County'].str.strip()

# %%
# now let's retain only those rows with data from NYC boroughs
nyc_registration_df = new_registration_df[(new_registration_df["County"]== "QUEENS") |
                                          (new_registration_df["County"]== "KINGS") |
                                          (new_registration_df["County"]== "NEW YORK") |
                                          (new_registration_df["County"]== "BRONX") |
                                          (new_registration_df["County"]== "RICHMOND")]

nyc_registration_df['County'].value_counts()
# Out:
# QUEENS      857635
# KINGS       536248
# BRONX       296304
# RICHMOND    275019
# NEW YORK    257469
# Name: County, dtype: int64

# %%
# finally, let's rename our columns in snake-case
nyc_registration_df.columns = ['id', 'registration_class', 'city', 'state', 'zip', 'county', 
                               'model_year','make', 'body_type', 'unladen_weight', 
                               'reg_valid_date','reg_expiration_date', 'color', 
                               'suspension_indicator','revocation_indicator']

# %%
nyc_registration_df.head()
# Out:
#                    id registration_class             city state    zip  \
# 8   5NPE24AF5FH207280                PAS  BROOKLYN           NY  11234
# 17  JF2GPAPC3F8301020                PAS  BROOKLYN           NY  11249
# 19  JF2GPAPC3F8296840                PAS  BAYSIDE            NY  11360
# 20  5NPE24AF5FH206243                PAS  FLUSHING           NY  11358
# 23  JF2GPAPC3F8288964                PAS  NEW YORK           NY  10069
#
#       county  model_year   make body_type  unladen_weight reg_valid_date  \
# 8      KINGS      2015.0  HYUND     SEDAN          3252.0     04/29/2018
# 17     KINGS      2015.0  SUBAR     SEDAN          3241.0     07/14/2017
# 19    QUEENS      2015.0  SUBAR  SUBURBAN          3241.0     05/01/2019
# 20    QUEENS      2015.0  HYUND     SEDAN          3252.0     10/16/2018
# 23  NEW YORK      2015.0  SUBAR  SUBURBAN          3241.0     12/07/2018
#
#    reg_expiration_date  color suspension_indicator revocation_indicator
# 8           05/23/2020  GY                       N                    N
# 17          08/21/2019  BK                       N                    N
# 19          03/11/2020  GY                       N                    N
# 20          10/15/2020  RD                       N                    N
# 23          05/02/2020  RD                       N                    N

# %%
# create database connection
connection_string = "postgres:chumwater@localhost:5432/ny_vehicles_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm table exists
engine.table_names()
# Out:
# ['ny_registration', 'nyc_veh_registration']

# %%
# load dataframe into database
nyc_registration_df.to_sql(name='nyc_veh_registration', con=engine, if_exists='append', index=False)

# %%
# output dataframe to CSV
nyc_registration_df.to_csv("nyc_registration.csv", index=True, header=True)

# %% [markdown]
# ## Vehicle Collision Data

# %%
collision_csv_file = "NYPD_Motor_Vehicle_Collisions.csv"
vehicle_collision_df = pd.read_csv(collision_csv_file)
# Out:
# /Users/scottgregory/anaconda2/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
vehicle_collision_df.head()
# Out:
#          DATE  TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  07/12/2019  0:00     BRONX    10472  40.831623  -73.86726
# 1  07/12/2019  0:00  BROOKLYN    11207  40.669792  -73.89240
# 2  07/12/2019  0:00  BROOKLYN    11234  40.618717  -73.93262
# 3  07/12/2019  0:00       NaN      NaN  40.829155  -73.93728
# 4  07/12/2019  0:00       NaN      NaN  40.718987  -73.94635
#
#                  LOCATION                    ON STREET NAME  \
# 0  (40.831623, -73.86726)  WESTCHESTER AVENUE
# 1   (40.669792, -73.8924)  SUTTER AVENUE
# 2  (40.618717, -73.93262)                               NaN
# 3  (40.829155, -73.93728)  8 AVENUE
# 4  (40.718987, -73.94635)  BROOKLYN QUEENS EXPRESSWAY
#
#        CROSS STREET NAME                           OFF STREET NAME  ...  \
# 0  SAINT LAWRENCE AVENUE                                       NaN  ...
# 1           WYONA STREET                                       NaN  ...
# 2                    NaN  2098      FLATBUSH AVENUE                 ...
# 3                    NaN                                       NaN  ...
# 4                    NaN                                       NaN  ...
#
#    CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                            NaN                            NaN
# 1                    Unspecified                            NaN
# 2                    Unspecified                            NaN
# 3                    Unspecified                            NaN
# 4                    Unspecified                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY  \
# 0                            NaN                            NaN     4168556
# 1                            NaN                            NaN     4169745
# 2                            NaN                            NaN     4169938
# 3                            NaN                            NaN     4169906
# 4                            NaN                            NaN     4168595
#
#                    VEHICLE TYPE CODE 1                  VEHICLE TYPE CODE 2  \
# 0                                Sedan                                  NaN
# 1  Station Wagon/Sport Utility Vehicle                                 Bike
# 2  Station Wagon/Sport Utility Vehicle  Station Wagon/Sport Utility Vehicle
# 3                                Sedan  Station Wagon/Sport Utility Vehicle
# 4                                Sedan                                Sedan
#
#    VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]
